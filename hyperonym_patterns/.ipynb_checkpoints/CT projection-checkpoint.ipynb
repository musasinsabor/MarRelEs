# %%
import fast_checker as fast_checker
import pandas as pd
import re

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# all_test = fast_checker.CTProjection("all")
test_e = fast_checker.CTProjection("economy")
# test = fast_checker.CTProjection("medicine")

# %% [markdown]
# ## CT extraction

# %%
test_e.df_terms
# Out:
#      Candidat de regroupement  Fréquence  Spécificité  \
# 0                 vencimiento        227       176.41
# 1                        meff        106       138.47
# 2                        fija        105       137.81
# 3             salario nominal         92       126.84
# 4                  meff renta         86       124.59
# ...                       ...        ...          ...
# 2284                 utilizar         59         3.75
# 2285            completamente         27         3.75
# 2286                      uso         57         3.68
# 2287                  ventaja         29         3.63
# 2288                diferente         82         3.58
#
#                       Variantes orthographiques       Matrice
# 0                    vencimiento___vencimientos           Nom
# 1                                          meff           Nom
# 2                                          fija           Nom
# 3          salario nominal___salarios nominales  Nom Adjectif
# ...

# %% [markdown]
# ## CT Projection

# %%
H01 = test_e.ct_projection("Hyp/etape4/H01_economy.csv", "H01")
# Out:
# total occurrences 166
# terms in left: 58.433734939759034%
# terms in right: 48.795180722891565%
# Hyp/etape4/H01_economy.csv CM projected
# Hyp/etape4/H01_economy.csv saved

# %%
H34=test_e.ct_projection("Hyp/etape4/H34_economy.csv", "H34")
# Out:
# total occurrences 179
# terms in left: 46.36871508379888%
# terms in right: 26.81564245810056%
# Hyp/etape4/H34_economy.csv CM projected
# Hyp/etape4/H34_economy.csv saved

# %% [markdown]
# ## Visualisation

# %%
H01
# Out:
#       id    subid    topic relational_semantic_type presence  \
# 0    H01    H01_1  economy           hyp_attributif     both
# 1    H01    H01_2  economy           hyp_attributif     both
# 2    H01    H01_3  economy           hyp_attributif     both
# 3    H01    H01_4  economy           hyp_attributif    right
# 4    H01    H01_5  economy           hyp_attributif     left
# ..   ...      ...      ...                      ...      ...
# 161  H01  H01_162  economy           hyp_attributif     none
# 162  H01  H01_163  economy           hyp_attributif     left
# 163  H01  H01_164  economy           hyp_attributif    right
# 164  H01  H01_165  economy           hyp_attributif     none
# 165  H01  H01_166  economy           hyp_attributif     both
#
#                                     candidate_term_left candidate_term_right  \
# 0    ['índice', 'integración', 'índice de integración']         ['promedio']
# ...
